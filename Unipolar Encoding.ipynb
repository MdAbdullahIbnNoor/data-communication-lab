# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_input=input()
data=[int(i) for i in data_input]
Time=np.arange(len(data)+1)
signal_1=np.zeros(len(data)+1,dtype=int)
for i in range(len(data)):
    if data[i]==0:
        signal_1[i]=0
    else:
        signal_1[i]=1
# Out:
# 0101

# %%
plt.title("UNIPOLAR ENCODDING")
plt.ylabel("Amplitude")
plt.xlabel("Time")
plt.step(Time,signal_1,where="post")
plt.text(1,2,data)
plt.grid(True)
plt.yticks([-3,-2,-1,0,1,2,3])
plt.xticks(Time)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming Time and signal_1 are defined as in your previous question
Time = np.arange(len(data) + 1)
signal_1 = np.zeros(len(data) + 1, dtype=int)

# Creating a step plot
plt.step(Time, signal_1, where="post")

# Adding labels and title
plt.xlabel('Time')
plt.ylabel('Signal')
plt.title('Step Plot of Signal over Time')

# Display the plot
plt.show()
