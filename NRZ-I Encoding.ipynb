# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_input=input("Enter data value:")
# Out:
# Enter data value:0101

# %%
data=[int(bit) for bit in data_input]


print(data)
# Out:
# [0, 1, 0, 1]

# %%
#data=[0,1,0,0,1,1,1,0]

bit=1
signal_list=[1]

for i in range(0,len(data)):
    if data[i]==1:
        if bit==1:
            bit=-1
        else:
            bit=1
    signal_list.append(bit)
print(signal_list)
# Out:
# [1, 1, -1, -1, 1]

# %%
Time=np.arange(0,len(signal_list))

plt.title("NRZ-I Encoding")
plt.ylabel("Amplitude")
plt.xlabel("Time")
plt.step(Time,signal_list)
plt.yticks([-3,-2,-1,0,1,2,3])
plt.xticks(Time)
plt.axhline(y=0,color="green")
plt.grid(True)

# %%
 import numpy as np
import matplotlib.pyplot as plt
data = [0,1,0,0,1,1,1,0]
bit= 1
signal_i=[1]
for i in range(0,len(data)):
    if data[i]==1:
        if bit==1:
            bit=-1
        else:
            bit=1
            
    signal_i.append(bit)
    
nrz_time=np.arange(0,len (signal_i))
#plt.subplot(311)
plt.grid(True)
plt.axhline (y=0, color="green")
plt.title("NRZ-I Encoding")
plt.xlabel("Time")
plt.ylabel("Amplitde")
plt.step(nrz_time,signal_i)
plt.yticks([-3,-2,-1,0,1,2,3])
plt.xticks(nrz_time)
plt.show()
